# %% [markdown]
# ## Image GPT [https://openai.com/blog/image-gpt/](https://openai.com/blog/image-gpt/)
#
# Demo notebook. Please follow the `Readme.md` file and install all the requiresments if you didn't already

# %%
# Run to check your nvidia card memory (optional)
# !nvidia-smi

# %%
import cv2
import os
import numpy as np
import pathlib
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from shutil import copy2
from datetime import datetime

from src.np_utils import color_quantize_np, generate_primer
# from src.runner import run_preds

model_size = "m"  # ["s", "m", "l"] available (xl, which is used on the website, is not avaiable)
gpus = 1
n_samples = 16
size = 32  # depends on the model: 32, *48, *64 (48 and 64 are only avaiable with XL model)

model_dir = "models"
color_clusters_dir = "clusters"
timestamp = datetime.today().strftime('%Y-%m-%d-%H:%M:%S')

# %% [markdown]
# ### Download model (run only once, if you have a model stored in `{model_dir}` then skip)
#
# Depends on your selection, get the right model and color cluster
#
# _This might take a while depends on your internet connection_

# %%
# Uncomment this code to download model and color cluster
# !python download.py --model {model_size} --ckpt 1000000 --clusters --download_dir {model_dir}/{model_size}
# !python download.py --clusters --download_dir {color_clusters_dir}
# Out:
# input args:
#  {
#     "download_dir":"models/l-small",
#     "bert":false,
#     "model":"l",
#     "ckpt":"131000",
#     "clusters":true,
#     "dataset":null
# }
# Fetching model.ckpt-131000.data-00000-of-00064: 1.00kit [00:00, 707kit/s]
# Fetching model.ckpt-131000.data-00001-of-00064: 252Mit [00:21, 11.5Mit/s]
# Fetching model.ckpt-131000.data-00002-of-00064: 249Mit [00:21, 11.5Mit/s]
# Fetching model.ckpt-131000.data-00003-of-00064: 249Mit [00:20, 12.0Mit/s]
# Fetching model.ckpt-131000.data-00004-of-00064: 274Mit [00:23, 11.6Mit/s]
# Fetching model.ckpt-131000.data-00005-of-00064: 255Mit [00:21, 12.0Mit/s]
# Fetching model.ckpt-131000.data-00006-of-00064: 255Mit [00:20, 12.6Mit/s]
# Fetching model.ckpt-131000.data-00007-of-00064: 264Mit [00:21, 12.2Mit/s]
# Fetching model.ckpt-131000.data-00008-of-00064: 245Mit [00:21, 11.6Mit/s]
# Fetching model.ckpt-131000.data-00009-of-00064: 258Mit [00:20, 12.5Mit/s]
# Fetching model.ckpt-131000.data-00010-of-00064: 245Mit [00:19, 12.5Mit/s]
# Fetching model.ckpt-131000.data-00011-of-00064: 255Mit [00:20, 12.5Mit/s]
# Fetching model.ckpt-131000.data-00012-of-00064: 255Mit [00:21, 12.0Mit/s]
# Fetching model.ckpt-131000.data-00013-of-00064: 283Mit [00:23, 12.1Mit/s]
# Fetching model.ckpt-131000.data-00014-of-00064: 255Mit [00:22, 11.5Mit/s]
# Fetching model.ckpt-131000.data-00015-of-00064: 274Mit [00:22, 12.0Mit/s]
# Fetching model.ckpt-131000.data-00016-of-00064: 283Mit [00:24, 11.5Mit/s]
# Fetching model.ckpt-131000.data-00017-of-00064: 245Mit [00:20, 12.0Mit/s]
# Fetching model.ckpt-131000.data-00018-of-00064: 274Mit [00:22, 12.0Mit/s]
# Fetching model.ckpt-131000.data-00019-of-00064: 245Mit [00:26, 9.22Mit/s]
# Fetching model.ckpt-131000.data-00020-of-00064: 245Mit [00:20, 11.9Mit/s]
# Fetching model.ckpt-131000.data-00021-of-00064: 264Mit [00:21, 12.5Mit/s]
# Fetching model.ckpt-131000.data-00022-of-00064: 245Mit [00:25, 9.71Mit/s]
# Fetching model.ckpt-131000.data-00023-of-00064: 255Mit [00:20, 12.5Mit/s]
# Fetching model.ckpt-131000.data-00024-of-00064: 255Mit [00:21, 11.9Mit/s]
# Fetching model.ckpt-131000.data-00025-of-00064: 274Mit [00:22, 12.0Mit/s]
# Fetching model.ckpt-131000.data-00026-of-00064: 255Mit [00:20, 12.6Mit/s]
# Fetching model.ckpt-131000.data-00027-of-00064: 245Mit [00:21, 11.5Mit/s]
# Fetching model.ckpt-131000.data-00028-of-00064: 245Mit [00:19, 12.5Mit/s]
# Fetching model.ckpt-131000.data-00029-of-00064: 255Mit [00:26, 9.50Mit/s]
# Fetching model.ckpt-131000.data-00030-of-00064: 245Mit [00:19, 12.5Mit/s]
# Fetching model.ckpt-131000.data-00031-of-00064: 255Mit [00:21, 12.0Mit/s]
# Fetching model.ckpt-131000.data-00032-of-00064: 283Mit [00:23, 12.0Mit/s]
# Fetching model.ckpt-131000.data-00033-of-00064: 255Mit [00:22, 11.5Mit/s]
# Fetching model.ckpt-131000.data-00034-of-00064: 264Mit [00:21, 12.5Mit/s]
# Fetching model.ckpt-131000.data-00035-of-00064: 264Mit [00:22, 11.5Mit/s]
# Fetching model.ckpt-131000.data-00036-of-00064: 255Mit [00:21, 12.0Mit/s]
# Fetching model.ckpt-131000.data-00037-of-00064: 264Mit [00:22, 11.5Mit/s]
# Fetching model.ckpt-131000.data-00038-of-00064: 274Mit [00:23, 11.5Mit/s]
# Fetching model.ckpt-131000.data-00039-of-00064: 264Mit [00:22, 12.0Mit/s]
# Fetching model.ckpt-131000.data-00040-of-00064: 255Mit [00:20, 12.5Mit/s]
# Fetching model.ckpt-131000.data-00041-of-00064: 283Mit [00:22, 12.5Mit/s]
# Fetching model.ckpt-131000.data-00042-of-00064: 255Mit [00:21, 12.0Mit/s]
# Fetching model.ckpt-131000.data-00043-of-00064: 274Mit [00:24, 11.0Mit/s]
# Fetching model.ckpt-131000.data-00044-of-00064: 274Mit [00:22, 12.0Mit/s]
# Fetching model.ckpt-131000.data-00045-of-00064: 245Mit [00:20, 12.0Mit/s]
# Fetching model.ckpt-131000.data-00046-of-00064: 245Mit [00:24, 9.96Mit/s]
# Fetching model.ckpt-131000.data-00047-of-00064: 277Mit [00:43, 6.33Mit/s]
# Fetching model.ckpt-131000.data-00048-of-00064: 245Mit [00:20, 12.0Mit/s]
# Fetching model.ckpt-131000.data-00049-of-00064: 245Mit [00:19, 12.5Mit/s]
# Fetching model.ckpt-131000.data-00050-of-00064: 264Mit [00:22, 12.0Mit/s]
# Fetching model.ckpt-131000.data-00051-of-00064: 280Mit [00:23, 12.1Mit/s]
# Fetching model.ckpt-131000.data-00052-of-00064: 264Mit [00:22, 12.0Mit/s]
# Fetching model.ckpt-131000.data-00053-of-00064: 264Mit [00:22, 12.0Mit/s]
# Fetching model.ckpt-131000.data-00054-of-00064: 249Mit [00:19, 12.5Mit/s]
# Fetching model.ckpt-131000.data-00055-of-00064: 245Mit [00:19, 12.5Mit/s]
# Fetching model.ckpt-131000.data-00056-of-00064: 255Mit [00:20, 12.5Mit/s]
# Fetching model.ckpt-131000.data-00057-of-00064: 274Mit [00:21, 12.5Mit/s]
# Fetching model.ckpt-131000.data-00058-of-00064: 264Mit [00:22, 12.0Mit/s]
# Fetching model.ckpt-131000.data-00059-of-00064: 274Mit [00:21, 12.5Mit/s]
# Fetching model.ckpt-131000.data-00060-of-00064: 264Mit [00:21, 12.4Mit/s]
# Fetching model.ckpt-131000.data-00061-of-00064: 249Mit [00:21, 11.5Mit/s]
# Fetching model.ckpt-131000.data-00062-of-00064: 280Mit [00:23, 12.0Mit/s]
# Fetching model.ckpt-131000.data-00063-of-00064: 245Mit [00:20, 12.0Mit/s]
# Fetching model.ckpt-131000.index: 18.0kit [00:00, 5.80Mit/s]
# Fetching model.ckpt-131000.meta: 35.8Mit [00:03, 9.92Mit/s]
# Fetching kmeans_centers.npy: 7.00kit [00:00, 4.71Mit/s]
# input args:
#  {
#     "download_dir":"clusters",
#     "bert":false,
#     "model":null,
#     "ckpt":null,
#     "clusters":true,
#     "dataset":null
# }
# Fetching kmeans_centers.npy: 7.00kit [00:00, 3.30Mit/s]

# %% [markdown]
# ## Define arguments and method call

# %%
#set model hyperparameters
MODELS={"l":(1536,16,48),"m":(1024,8,36),"s":(512,8,24) }
n_embd,n_head,n_layer=MODELS[model_size]

# %% [markdown]
# ## Generate n_samples for a given primer
# Samples are stored in `out/` dir. This might take a while to execute, depends on your GPU. If you're geting an error, try smaller model (i.e. `model_size = "s"`). If it's taking too long then decrease `n_samples`.

# %%
# Runs sampling for a given primer
# !python src/run.py --sample --n_embd {n_embd} --n_head {n_head} --n_layer {n_layer} --ckpt_path {model_dir}/{model_size}/model.ckpt-1000000  --color_cluster_path {color_clusters_dir}/kmeans_centers.npy --save_dir out --n_gpu 1 --n_px {size} --n_sub_batch {n_samples} --seed 0
# Out:
# input args:
#  {
#     "data_path":"/root/downloads/imagenet",
#     "ckpt_path":"models/m/model.ckpt-1000000",
#     "color_cluster_path":"clusters/kmeans_centers.npy",
#     "save_dir":"out",
#     "n_embd":1024,
#     "n_head":8,
#     "n_layer":36,
#     "n_px":32,
#     "n_vocab":512,
#     "bert":false,
#     "bert_mask_prob":0.15,
#     "clf":false,
#     "n_sub_batch":16,
#     "n_gpu":1,
#     "eval":false,
#     "sample":true,
#     "seed":0,
#     "primer":null
# }
# None
# 0
# WARNING:tensorflow:From /home/piro/anaconda3/envs/image-gpt/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# trainable parameters: 455157760
# 2021-03-02 12:12:11.793334: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# 2021-03-02 12:12:11.816582: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 3499910000 Hz
# 2021-03-02 12:12:11.817511: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x55dc73fad270 executing computations on platform Host. Devices:
# 2021-03-02 12:12:11.817559: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# 2021-03-02 12:12:11.919804: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1433] Found device 0 with properties:
# name: GeForce GTX 1080 Ti major: 6 minor: 1 memoryClockRate(GHz): 1.6325
# pciBusID: 0000:65:00.0
# totalMemory: 10.91GiB freeMemory: 9.41GiB
# 2021-03-02 12:12:11.919835: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1512] Adding visible gpu devices: 0
# 2021-03-02 12:12:11.920371: I tensorflow/core/common_runtime/gpu/gpu_device.cc:984] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-03-02 12:12:11.920384: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990]      0
# 2021-03-02 12:12:11.920393: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1003] 0:   N
# 2021-03-02 12:12:11.920456: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 9154 MB memory) -> physical GPU (device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:65:00.0, compute capability: 6.1)
# 2021-03-02 12:12:11.921908: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x55dc717b4740 executing computations on platform CUDA. Devices:
# 2021-03-02 12:12:11.921925: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): GeForce GTX 1080 Ti, Compute Capability 6.1
# WARNING:tensorflow:From /home/piro/anaconda3/envs/image-gpt/lib/python3.7/site-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
#   0%|                                                  | 0/1024 [00:00<?, ?it/s]2021-03-02 12:12:19.311401: I tensorflow/stream_executor/dso_loader.cc:152] successfully opened CUDA library libcublas.so.10.0 locally

# %%
# Copy results to temp folder with postfix
for i in range(gpus*n_samples):
    source_path = f'out/sample_{i}.png'
    dest_path = f'copies/sample_{i}_{timestamp}.png'
    if os.path.isfile(dest_path):
        print(f"Cannot copy {source_path}.png to {dest_path}, file already exists")
    else:
        copy2(source_path, dest_path)

# %% [markdown]
# ## Print currently stored samples

# %%
num_columns = 4
num_rows = int(gpus*n_samples/num_columns)
fig, ax = plt.subplots(num_rows,num_columns, dpi=300, figsize = (2*num_columns,2*num_rows))

i = 0
for i in range(num_rows):
    for j in range(num_columns):
        idx = i*num_columns+j
        source_path = f'out/sample_{idx}.png'
        image = plt.imread(source_path)
        ax[i, j].imshow(image, interpolation="none")
    i += 1
    
plt.show()
